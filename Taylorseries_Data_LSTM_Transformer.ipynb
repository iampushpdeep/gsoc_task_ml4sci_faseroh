# %% [markdown]
# <a href="https://colab.research.google.com/github/iampushpdeep/gsoc_task_ml4sci_faseroh/blob/main/Taylorseries_Data_LSTM_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FASEROH Task - 1 Generate Taylor Series Data
# ## Pushpdeep Singh(pushpdeep30@gmail.com)
# ### (I am using taylor series data around zero) (Also, many polynomials fucntions have taylor series equal to themselves so I ignore them so our model doesn't learn y=x function)(This dataset file is uploaded on my github repo - )

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
import functools
from random import choices
import time
import sympy as sp
x = sp.Symbol('x')
import numpy as np

# leaves and binary operators
leaves = ["x", "-5", "-4", "-3", "-2", "-1", "1", "2", "3", "4", "5"]
p_leaf = [2/3, 1/30, 1/30, 1/30, 1/30, 1/30, 1/30, 1/30, 1/30, 1/30, 1/30]
binary_operators = ["+", "-", "*", "/"]
unary_operators = ["exp", "sqrt", "sin", "cos", "tan", "sinh", "cosh", "tanh", "asin", "acos", "atan", "asinh", "acosh", "atanh"]


@functools.lru_cache(128)
def unary_binary_subtrees(e, n):
    """ calculate D(e, n), helper for distribution_k_a """
    if e==0:
        return 0
    elif n==0:
        return 1
    else:
        return unary_binary_subtrees(e-1, n) + unary_binary_subtrees(e, n-1) + unary_binary_subtrees(e+1, n-1)


def distribution_k_a(e, n):
    """ distribution over position k(e, n) """
    population = []
    weights = []
    for k in range(e):
        population.append( (k, 1))
        e_n = unary_binary_subtrees(e, n)
        weights.append(unary_binary_subtrees(e-k, n-1)/e_n)
        population.append((k, 2))
        weights.append(unary_binary_subtrees(e-k+1, n-1)/e_n)
    return population, weights


class NodeBinary:
    operator = True
    binary = True
    operand = False
    def __init__(self, data, left=None, right=None):
        self.data = data
        self.left = left
        self.right = right


class NodeUnary:
    operator = True
    binary = False
    operand = False
    def __init__(self, data, middle=None):
        self.data = data
        self.middle = middle


class Leaf:
    operator = False
    binary = False
    operand = True
    def __init__(self, data):
        self.data = data


def random_binary_trees(n):
    """
    Generates a random binary tree
    see Appendix C:
        n = num nodes
        k = position
        a = arity (unary or binary operator)
        e = number of empty nodes
    """
    population, weights = distribution_k_a(1, n)
    k, a = choices(population, weights)[0]

    #  select root node
    if a == 1:
        operator = choices(unary_operators)[0]
        node = NodeUnary(operator)
        empty_node = [(node, 'middle')]
        e = 1
    else:
        operator = choices(binary_operators)[0]
        node = NodeBinary(operator)
        empty_node = [(node, 'left'), (node, 'right')]
        e = 2

    #  making the tree
    n = n - 1
    while n > 0:
        population, weights = distribution_k_a(e, n)
        k, a = choices(population, weights)[0]
        i = 0
        new_empty_node = []
        for ele in empty_node:
            if i < k:
                leave = choices(leaves, p_leaf)[0]
                value = Leaf(leave)
                setattr(ele[0], ele[1], value)
            elif i == k:
                if a == 1:
                    operator = choices(unary_operators)[0]
                    value = NodeUnary(operator)
                    setattr(ele[0], ele[1], value)
                    if ele[1] == 'left':
                        new_ele = ele[0].left
                    elif ele[1] == 'middle':
                        new_ele = ele[0].middle
                    else:
                        new_ele = ele[0].right
                    new_empty_node = [(new_ele, 'middle')]
                    e = e - k
                else:
                    operator = choices(binary_operators)[0]
                    value = NodeBinary(operator)
                    setattr(ele[0], ele[1], value)
                    if ele[1] == 'left':
                        new_ele = ele[0].left
                    elif ele[1] == 'middle':
                        new_ele = ele[0].middle
                    else:
                        new_ele = ele[0].right
                    new_empty_node = [(new_ele, 'left'), (new_ele, 'right')]
                    e = e - k + 1
            else:
                new_empty_node.append(ele)
            i += 1
        empty_node = new_empty_node
        n = n - 1

    if len(empty_node) != 0:
        for ele in empty_node:
            leave = choices(leaves, p_leaf)[0]
            value = Leaf(leave)
            setattr(ele[0], ele[1], value)

    return node


def traverse_unary_binary_prefix(root, seq=None, verbose=False):
    """ traverses a binary expression tree and generates prefix notation """
    if not seq:
        seq = []

    if verbose:
        print(root.data)

    seq.append(root.data)

    if root.binary:
        if root.left.operator:
            traverse_unary_binary_prefix(root.left, seq)
        else:
            if verbose:
                print(root.left.data)
            seq.append(root.left.data)

        if root.right.operator:
            traverse_unary_binary_prefix(root.right, seq)
        else:
            if verbose:
                print(root.right.data)
            seq.append(root.right.data)
    else:
        if root.middle.operator:
            traverse_unary_binary_prefix(root.middle, seq)
        else:
            if verbose:
                print(root.middle.data)
            seq.append(root.middle.data)

    return seq

# %%
import random

from sympy import *



OPERATORS = set(['+', '-', '*', '/', '(', ')', 'pow'])

UNARY_OPERATORS = set(["exp", "sqrt", "sin", "cos", "tan", "asin", "acos", "atan", "sinh", "cosh", "tanh", "asinh", "acosh", "atanh"])

operator_class = ["<class 'sympy.core.add.Add'>", "<class 'sympy.core.mul.Mul'>", "<class 'sympy.core.power.Pow'>", "exp", "sin", "cos", "tan", "asin", "acos", "atan", "sinh", "cosh", "tanh", "asinh", "acosh", "atanh", "Abs"]

operator_dict = {"<class 'sympy.core.add.Add'>": "+", "<class 'sympy.core.mul.Mul'>": "*", "<class 'sympy.core.power.Pow'>": "pow", "exp": "exp", "sin": "sin", "cos": "cos", "tan": "tan", "asin": "asin", "acos": "acos", "atan": "atan", "sinh": "sinh", "cosh": "cosh", "tanh": "tanh", "asinh": "asinh", "acosh": "acosh", "atanh": "atanh", "Abs": "abs"}

rational_number = ["<class 'sympy.core.numbers.Rational'>", "<class 'sympy.core.numbers.Half'>"]

exp1_number = ["<class 'sympy.core.numbers.Exp1'>"]

invalid_function = ["<class 'sympy.core.numbers.ImaginaryUnit'>", "<class 'sympy.core.numbers.ComplexInfinity'>", "<class 'sympy.core.numbers.NegativeInfinity'>", "<class 'sympy.core.numbers.Infinity'>", "<class 'sympy.core.numbers.NaN'>"]

invalid_expression = ["zoo", "oo", "I", "-oo"]

#x = symbols('x')
def infix_to_prefix(expr, seq=None):
    if not seq:
        seq = []
    s1 = str(expr)
    s2 = str(expr.func)
    if s1 in invalid_expression or s2 in invalid_function:
        return False
    length = len(expr.args)
    if s2 in operator_class:
        op = operator_dict[s2]
        seq.append(op)
    elif s2 in rational_number:
        s1 = s1.split("/")
        seq.append("/")
        seq.append(s1[0])
        seq.append(s1[1])
    elif s2 in exp1_number:
        seq.append("exp")
        seq.append("1")
    else:
        seq.append(s1)

    for i in range(length):
        if i!=0 and i!=(length-1):
            seq.append(op)
        arg = expr.args[i]
        feedback = infix_to_prefix(arg, seq)
        if feedback==False:
            return False
    return seq

### PREFIX ===> INFIX ###
'''
Scan the formula reversely
1) When the token is an operand, push into stack
2) When the token is an operator, pop out 2 numbers from stack, merge them and push back to the stack
'''
def prefix_to_infix(formula):
    stack = []
    for ch in reversed(formula):
        if ch not in OPERATORS and ch not in UNARY_OPERATORS:
            stack.append(ch)
        else:
            if ch in OPERATORS:
                a = stack.pop()
                b = stack.pop()
                exp = "(" + " " + a + " " + ch + " " + b + " " + ")"  
            else:
                a = stack.pop()
                exp = ch + " " + "(" + " " +  a + " " +")"
            stack.append(exp)
    return stack[-1].split()

# %%
import random
import time

from sympy import Symbol, diff, simplify

# %%
_FINISH = False
x = Symbol('x', real=True) # TODO


def simplify_timeout(expr):
    from multiprocessing import Process, Manager

    result = None
    def f(d, expr):
        from sympy import S; S.Half
        try:
            d['result'] = simplify(expr)
        except:
            d['result'] = "Error"

    with Manager() as manager:
        d = manager.dict()
        p = Process(target=f, args=(d, expr))
        p.start()
        p.join(timeout=3)
        if p.is_alive():
            p.terminate()
        else:
            result = d["result"]
    if result==None:
        return expr
    elif str(type(result))=="<class 'sympy.calculus.util.AccumulationBounds'>":
        return "Error"
    else:
        return result

def series_timeout(ff):
  from multiprocessing import Process, Manager
  expr = None
  def f(d, ff):
      from sympy import S; S.Half
      try:
          d['expr'] = ff.series(x, 0, 5).removeO()
      except:
          d['expr'] = "Error"

  with Manager() as manager:
      d = manager.dict()
      p = Process(target=f, args=(d, ff))
      p.start()
      p.join(timeout=3)
      if p.is_alive():
          p.terminate()
      else:
          expr = d["expr"]


  if expr==None:
      return expr

  else:
    return expr

def parse_expr_timeout(string):
    from multiprocessing import Process, Manager
    from sympy.parsing.sympy_parser import parse_expr

    expr = None
    def f(d, string):
        from sympy import S; S.Half
        try:
            d['expr'] = parse_expr(string, local_dict={'x': x}, evaluate=False)
        except:
            return None

    with Manager() as manager:
        d = manager.dict()
        p = Process(target=f, args=(d, string))
        p.start()
        p.join(timeout=3)
        if p.is_alive():
            p.terminate()
        else:
            expr = d["expr"]

    return expr

# %%
cd taylor/data_generation
# Out:
# /content/drive/MyDrive/taylor/data_generation

# %%
def generate_single_sequence():
    n = random.randint(1, 3)
    root = random_binary_trees(n)
    result = traverse_unary_binary_prefix(root)
    if 'x' not in result:
        return None

    result_infix = prefix_to_infix(result)
    result_expr = " ".join(result_infix)

    #  convert to sympy expression
    result_expr = parse_expr_timeout(result_expr)
    if result_expr is None:
        return None

    #REJECT IF POLYNOMIAL
    if result_expr.is_polynomial():
      return None

    #  simplification
    result_simp = simplify_timeout(result_expr)
    if result_simp == "Error":
        return None
    
        
    #  back to prefix
    result_simp_prefix = infix_to_prefix(result_simp)
    if not result_simp_prefix:
        return None

    #  generate target
    try:
        taylor_expn =  series_timeout(result_simp)
    except ValueError:
        return None
    if taylor_expn == "Error" or None:
      return None

    expression = simplify_timeout(taylor_expn)
    
    if expression == "Error":
        return None
        
    expression_prefix = infix_to_prefix(expression)
    if not expression_prefix:
        return None

    if expression_prefix == result_simp_prefix or len(expression_prefix)>50: 
      return None

    expression_prefix = " ".join(expression_prefix)
    result_simp_prefix = " ".join(result_simp_prefix)
    return expression_prefix, result_simp_prefix


def generate_bwd(num):
    filename = "taylor_data_10000.txt"
    

    while True:
        if _FINISH:
            break
        sequence = []
        start = time.time()
        file = open(filename, "a")
        i = 1
        while i<=num:
            seq = generate_single_sequence()
            if seq is not None:
                expression_prefix, result_simp_prefix = seq
                sequence.append(result_simp_prefix + "\t" + expression_prefix + "\n")
                print((result_simp_prefix + "\t" + expression_prefix + "\n"))
                file.write(result_simp_prefix + "\t" + expression_prefix + "\n")
            else:
                continue
            i += 1

        end = time.time()
        print('process finished')
        
        file.close()
        return sequence

# %%
generate_bwd(10000)
# Out:
# * cosh x exp 5	* / 1 24 * + 24 + pow x 4 * 12 pow x 2 exp 5
#
# cos + -1 pow x 2	+ * pow x 2 sin 1 + * / -1 2 * pow x 4 cos 1 cos 1
#
# sinh x	+ x * / 1 6 pow x 3
#
# * pow x 2 asinh x	pow x 3
#
# pow + 1 * -1 x / 1 2	+ 1 + * / -5 128 pow x 4 + * / -1 2 x + * / -1 8 pow x 2 * / -1 16 pow x 3
#
# + * -1 x cos + 5 x	+ * -1 x + * -1 * x sin 5 + * / -1 2 * pow x 2 cos 5 + * / 1 6 * pow x 3 sin 5 + * / 1 24 * pow x 4 cos 5 cos 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a539e182727c> in <cell line: 1>()
# ----> 1 generate_bwd(10000)
#
# <ipython-input-10-8f2d5817fc43> in generate_bwd(num)
#      66         i = 1
#      67         while i<=num:
# ---> 68             seq = generate_single_sequence()
#      69             if seq is not None:
#      70                 expression_prefix, result_simp_prefix = seq
#
# <ipython-input-10-8f2d5817fc43> in generate_single_sequence()
#      31     #  generate target
#      32     try:
# ---> 33         taylor_expn =  series_timeout(result_simp)
#      34     except ValueError:
#      35         return None
#
# <ipython-input-6-93e2fcde689e> in series_timeout(ff)
#      44       p = Process(target=f, args=(d, ff))
#      45       p.start()
# ---> 46       p.join(timeout=3)
#      47       if p.is_alive():
#      48           p.terminate()
#
# /usr/lib/python3.9/multiprocessing/process.py in join(self, timeout)
#     147         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148         assert self._popen is not None, 'can only join a started process'
# --> 149         res = self._popen.wait(timeout)
#     150         if res is not None:
#     151             _children.discard(self)
#
# /usr/lib/python3.9/multiprocessing/popen_fork.py in wait(self, timeout)
#      38             if timeout is not None:
#      39                 from multiprocessing.connection import wait
# ---> 40                 if not wait([self.sentinel], timeout):
#      41                     return None
#      42             # This shouldn't block if wait() returned successfully.
#
# /usr/lib/python3.9/multiprocessing/connection.py in wait(object_list, timeout)
#     929
#     930             while True:
# --> 931                 ready = selector.select(timeout)
#     932                 if ready:
#     933                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.9/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Task-2 Processing Data for Model

# %%
cd -
# Out:
# /content/drive/MyDrive

# %%
import os
import io
import numpy as np
import re
import unicodedata
import urllib3
import shutil
import zipfile
import itertools
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas
import spacy
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from tqdm import tqdm_notebook
import random
from collections import Counter
import torchtext
from torchtext.data import get_tokenizer
from tqdm import tqdm
import math

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')
    
def preprocess_sentence(w):
    w = unicode_to_ascii(w.lower().strip())
    return w

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [equation, series]
def create_dataset(path, num_examples=None):
    lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

    word_pairs = [[preprocess_sentence(w) for w in l.split('\t')]  for l in lines[:num_examples]]

    return zip(*word_pairs)

# %%
path_to_file = "./taylor/data_generation/taylor_cleaned_pre.txt"

# %%
eq, series = create_dataset(path_to_file)
print(eq[-1])
print(series[-1])
# Out:
# * / 1 3 * pow x -1 acos x
# * pow x -1 + * / -1 3 x + * / -1 18 pow x 3 + * / -1 40 pow x 5 * / 1 6 pi

# %%
X_text, Y_text = create_dataset(path_to_file)

# %%
device = torch.device("cuda" if torch.torch.cuda.is_available() else "cpu")

# %%
tokenizer = get_tokenizer(tokenizer = None, language = None)

# %%
class FunctionDataset(torch.utils.data.Dataset):

  def __init__(self, ops=3, max_seq_length=32):

    raw_input = []
    raw_output = []

    for i in range(len(X_text)):
      expr, tay = tokenizer(X_text[i]), tokenizer(Y_text[i])

      #discards expressions too long and nan values
      if(len(expr) + 2 <= max_seq_length and len(tay) + 2 <= max_seq_length):
        #insert start and end tokens
        expr.insert(0,'<SOS>')
        expr.append('<EOS>')

        tay.insert(0,'<SOS>')
        tay.append('<EOS>')
        
        raw_input.append(expr)
        raw_output.append(tay)
        print("expression", expr)
        print("taylor series around 0", tay)
    
    #generate vocab
    self.vocab = set()
    for expr, tay in zip(raw_input, raw_output):
      self.vocab |= set(expr) |(set(tay))

    #token -> idx
    self.token_to_idx = {value : index + 1 for index, value in enumerate(self.vocab)}

    #idx -> token
    self.idx_to_token = {index + 1 : value for index, value in enumerate(self.vocab)}

    self.input = []
    self.output = []
    for raw_expr, raw_tay in zip(raw_input, raw_output):
      expr = [self.token_to_idx[token] for token in raw_expr] + [0] * (max_seq_length - len(raw_expr))
      tay = [self.token_to_idx[token] for token in raw_tay] + [0] * (max_seq_length - len(raw_tay))

      self.input.append(torch.tensor(expr, dtype=torch.long, device=device))
      self.output.append(torch.tensor(tay, dtype=torch.long, device=device))
    
  def __len__(self):
    return len(self.input)

  def __getitem__(self, idx):
    return self.input[idx].to(device), self.output[idx].to(device)

  def get_alphabet(self):
    return self.vocab

# %%
d = FunctionDataset()
train_idx = list(range(0, int(9*len(d)/10)))
test_idx = list(range(int(9*len(d)/10), len(d)))
train_dataset = torch.utils.data.Subset(d, train_idx)
test_dataset = torch.utils.data.Subset(d, test_idx)
# Out:
# Streaming output truncated to the last 5000 lines.
# expression ['<SOS>', '+', '2', '*', '/', '1', '5', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '2', '+', '*', '/', '-1', '30', 'pow', 'x', '3', '*', '/', '1', '5', 'x', '<EOS>']
# expression ['<SOS>', 'sinh', '*', '/', '2', '5', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '2', '375', '*', 'x', '+', '75', '*', '2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-1', 'sinh', '*', 'x', 'pow', '+', '3', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '162', '*', 'x', '+', '-54', '+', '*', '-7', 'pow', 'x', '2', '+', '*', '3', 'pow', 'x', '3', '*', '18', 'x', '<EOS>']
# expression ['<SOS>', '+', 'x', '*', '4', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '+', '15', '*', '-2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', 'tanh', '5', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '-1', '3', '*', 'x', '*', '+', '-3', 'pow', 'x', '2', 'tanh', '5', '<EOS>']
# expression ['<SOS>', '+', '4', '*', 'pow', 'x', '-1', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '/', '-1', '3', 'pow', 'x', '2', '*', '/', '2', '15', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'tanh', '+', 'x', '*', '-1', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'pow', 'atanh', 'pow', 'x', '2', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', 'x', '<EOS>']
# expression ['<SOS>', 'cosh', '+', '5', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', 'pow', 'x', '2', 'sinh', '5', '+', '*', '/', '1', '2', '*', 'pow', 'x', '4', 'cosh', '5', 'cosh', '5', '<EOS>']
# expression ['<SOS>', '*', '-1', 'asin', '+', 'x', '*', '-1', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '/', '-1', '2', '*', 'pow', 'x', '-1', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '/', '-1', '2', '+', '*', '/', '-3', '80', 'pow', 'x', '4', '*', '/', '1', '12', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'atanh', 'atanh', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '1', '2', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '5', 'cos', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '/', '-5', '2', 'pow', 'x', '2', '*', '/', '25', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'exp', 'asin', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', 'x', '+', '*', '/', '1', '2', 'pow', 'x', '2', '*', '/', '-1', '8', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '-1', 'atanh', '*', '4', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-1', 'atanh', '4', '+', '*', '/', '-3', '50', 'pow', 'x', '4', '*', '/', '-2', '15', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'atanh', 'atan', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '4', '*', 'x', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '4', '3', '*', 'pow', 'x', '2', '+', '3', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '5', 'cosh', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '/', '5', '2', 'pow', 'x', '2', '*', '/', '25', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '-3', 'pow', 'atan', 'pow', 'x', '2', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'pow', 'x', '-2', '+', '-3', '*', '-1', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'atanh', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '1', '2', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-4', 'asin', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-4', '+', 'x', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'asinh', '*', '5', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '5', 'x', '*', '/', '-65', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'atanh', 'x', '-1', 'tanh', '4', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '-1', '45', '*', 'pow', 'x', '-1', '*', '+', '-45', '+', '*', '4', 'pow', 'x', '4', '*', '15', 'pow', 'x', '2', 'tanh', '4', '<EOS>']
# expression ['<SOS>', '*', '-1', 'asin', '*', '5', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-5', 'x', '*', '/', '-115', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'x', '+', '4', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '+', '12', '+', '*', '-1', 'pow', 'x', '3', '*', '3', 'x', '<EOS>']
# expression ['<SOS>', 'cosh', '*', '4', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '8', 'pow', 'x', '2', '*', '/', '32', '3', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '5', '*', 'x', 'pow', 'sinh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '6', '+', '*', '/', '-1', '6', 'pow', 'x', '2', '*', '/', '7', '360', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'x', '-1', '+', '4', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '5', 'pow', 'x', '-1', '+', '*', '/', '-1', '2', 'x', '*', '/', '1', '24', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'sinh', '+', 'x', '*', '-1', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '3', '+', 'x', 'acos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '3', '+', '*', '/', '1', '2', 'pi', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'exp', '*', 'x', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', 'pow', 'x', '2', '*', '/', '5', '6', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '/', '1', '3', '*', 'x', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '9', '*', 'pow', 'x', '2', '+', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '/', '3', '5', '*', '/', '-1', '5', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '/', '3', '5', '+', '*', '/', '-1', '5', 'x', '*', '/', '-1', '30', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-4', '*', 'x', 'pow', '+', '1', '*', '-16', 'pow', 'x', '2', '/', '-1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-32', 'pow', 'x', '3', '*', '-4', 'x', '<EOS>']
# expression ['<SOS>', 'atan', '*', 'x', 'atanh', '3', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', 'x', 'atanh', '3', '*', '/', '-1', '3', '*', 'pow', 'x', '3', 'pow', 'atanh', '3', '3', '<EOS>']
# expression ['<SOS>', 'pow', '+', 'x', '*', '-1', 'tan', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-3', 'pow', 'x', '-3', '+', '*', '/', '1', '175', 'x', '+', '*', '/', '2', '7875', 'pow', 'x', '3', '*', '/', '6', '5', 'pow', 'x', '-1', '<EOS>']
# expression ['<SOS>', '+', '2', '*', '-1', 'sinh', '*', '5', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '2', '+', '*', '-5', 'x', '*', '/', '-125', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'atanh', '5', 'exp', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '24', '*', '+', '-24', '+', '*', '-1', 'pow', 'x', '4', '+', '*', '-24', 'x', '+', '*', '-12', 'pow', 'x', '2', '*', '-4', 'pow', 'x', '3', 'atanh', '5', '<EOS>']
# expression ['<SOS>', '+', '*', '/', '1', '3', 'x', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '/', '1', '2', 'pow', 'x', '2', '+', '*', '/', '1', '3', 'x', '*', '/', '1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '-3', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-2', '+', '*', '/', '-1', '2', 'pow', 'x', '2', '*', '/', '1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'exp', 'pow', '+', '1', 'pow', 'x', '2', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '2', '*', 'exp', '1', '+', '2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'x', '*', '-2', 'acos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '-1', 'pi', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '4', '*', 'x', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '4', '3', '*', 'pow', 'x', '2', '+', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'exp', '*', '/', '-1', '5', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '/', '-1', '5', 'pow', 'x', '2', '*', '/', '1', '50', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'x', '+', 'x', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '6', '*', 'pow', 'x', '2', '+', '12', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', 'x', 'asin', '*', '4', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '+', '15', '*', '32', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'cos', '+', 'x', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', 'pow', 'x', '4', '*', '-2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'sinh', 'asin', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '-4', '*', '-1', 'cosh', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-5', '+', '*', '/', '-1', '2', 'pow', 'x', '2', '*', '/', '1', '8', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'x', 'sin', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'pow', 'x', '2', '*', '/', '-1', '2', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'atanh', '*', '3', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'sinh', '*', '/', '3', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '3', '16', '*', 'x', '+', '8', '*', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'tan', '*', 'x', '+', '-2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '+', '-6', '+', '*', '-8', 'pow', 'x', '2', '+', '*', '3', 'x', '*', '12', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '5', '+', 'x', 'exp', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '6', '+', '*', '/', '1', '2', 'pow', 'x', '2', '+', '*', '2', 'x', '+', '*', '/', '1', '6', 'pow', 'x', '3', '*', '/', '1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'x', 'exp', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '1', '+', 'x', '+', '*', '/', '1', '2', 'pow', 'x', '2', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'sinh', 'sin', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '*', '5', 'pow', 'x', '-1', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '5', 'pow', 'x', '-1', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-2', 'pow', 'atan', 'pow', 'x', '2', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '2', '3', '*', 'pow', 'x', '-2', '+', '-3', '*', '-1', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'tanh', '5', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '-1', 'tanh', '5', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'atanh', '*', 'x', 'pow', 'pi', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', 'x', 'pow', 'pi', '-1', '*', '/', '1', '3', '*', 'pow', 'pi', '-3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'sinh', '*', '7', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '7', 'x', '*', '/', '343', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'x', 'pow', '+', '-5', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '625', '*', 'x', '+', '-125', '+', '*', '-1', 'pow', 'x', '3', '+', '*', '-25', 'x', '*', '-5', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '3', 'asin', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '3', '2', '*', 'x', '+', '2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '3', '*', 'pow', 'x', '-1', 'pow', 'asinh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '5040', '*', 'pow', 'x', '-2', '+', '15120', '*', 'pow', 'x', '2', '+', '2520', '+', '*', '-714', 'pow', 'x', '2', '*', '367', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '-4', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-3', '+', '*', '/', '1', '2', 'pow', 'x', '2', '*', '/', '1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'pow', '+', '-5', 'x', '-1', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '1875', '*', 'x', '+', '375', '+', '*', '-110', 'pow', 'x', '2', '+', '*', '-22', 'pow', 'x', '3', '*', '75', 'x', '<EOS>']
# expression ['<SOS>', '+', '*', '/', '1', '3', 'x', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '+', '4', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'exp', 'asin', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', 'x', '+', '*', '/', '1', '2', 'pow', 'x', '2', '*', '/', '-1', '8', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'exp', '+', '/', '-1', '2', '*', '/', '1', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '384', '*', '+', '384', '+', 'pow', 'x', '4', '+', '*', '8', 'pow', 'x', '3', '+', '*', '48', 'pow', 'x', '2', '*', '192', 'x', 'exp', '/', '-1', '2', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'x', 'tan', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '2', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-2', '+', 'x', '*', '-1', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-2', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'sinh', '*', 'x', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'pow', 'x', '2', '*', '/', '1', '6', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'exp', 'tan', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', 'x', '+', '*', '/', '1', '2', 'pow', 'x', '2', '+', '*', '/', '1', '6', 'pow', 'x', '3', '*', '/', '1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'cosh', 'x', '-1', 'atan', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '24', '*', '+', '24', '+', '*', '-12', 'pow', 'x', '2', '*', '5', 'pow', 'x', '4', 'atan', '2', '<EOS>']
# expression ['<SOS>', '*', '5', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '5', '6', '*', 'x', '+', '6', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'tanh', 'sin', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'pow', 'cosh', 'x', '-1', 'sinh', '5', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '-1', '24', '*', '+', '24', '+', '*', '-12', 'pow', 'x', '2', '*', '5', 'pow', 'x', '4', 'sinh', '5', '<EOS>']
# expression ['<SOS>', '*', '/', '1', '5', '*', 'x', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '30', '*', 'pow', 'x', '2', '+', '6', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', 'pow', 'x', '/', '1', '2', '*', '-1', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'pow', 'x', '/', '1', '2', '+', '*', '-1', 'x', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', 'x', 'cosh', '*', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', 'x', '+', '*', '2', 'pow', 'x', '2', '*', '/', '2', '3', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '-3', 'asin', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '-3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '+', '1', 'x', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', 'x', '+', '*', '/', '1', '2', 'pow', 'x', '2', '+', '*', '/', '1', '2', 'pow', 'x', '3', '*', '/', '1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '-3', 'sinh', '*', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-3', '+', '*', '2', 'x', '*', '/', '4', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'sinh', 'tan', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-1', 'atan', '*', '5', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-5', 'x', '*', '/', '245', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'x', '-1', 'asinh', '*', '/', '1', '4', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '/', '1', '4', '+', '*', '/', '-1', '384', 'pow', 'x', '2', '*', '/', '3', '40960', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '5', '+', '*', '/', '1', '2', 'pi', '*', '-1', 'asin', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '/', '1', '2', 'pi', '+', '*', '-1', 'x', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'tanh', '*', 'x', '+', '-1', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '-1', '+', 'x', '+', '*', '-1', 'pow', 'x', '3', '*', '/', '1', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'x', '-2', 'tan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'pow', 'x', '-1', '+', '*', '/', '1', '3', 'x', '*', '/', '2', '15', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '*', '/', '1', '2', 'x', '*', '/', '-1', '2', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '12', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-5', 'cos', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-4', '+', '*', '/', '-1', '2', 'pow', 'x', '2', '*', '/', '-1', '8', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'tan', '*', 'x', 'pow', 'acosh', '-5', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', 'x', 'pow', 'acosh', '-5', '-1', '*', '/', '1', '3', '*', 'pow', 'x', '3', 'pow', 'acosh', '-5', '-3', '<EOS>']
# expression ['<SOS>', 'cos', 'cos', '*', '3', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '/', '-27', '8', '*', 'pow', 'x', '4', '+', '*', '3', 'cos', '1', 'sin', '1', '+', '*', '/', '9', '2', '*', 'pow', 'x', '2', 'sin', '1', 'cos', '1', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'x', '-1', 'acos', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-1', '+', '*', '/', '-1', '24', 'pow', 'x', '4', '+', '*', '/', '1', '6', 'pow', 'x', '2', '*', '/', '1', '2', '*', 'pi', 'pow', 'x', '-1', '<EOS>']
# expression ['<SOS>', '+', 'x', '*', '-1', 'tan', '*', '/', '1', '4', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '192', '*', 'x', '+', '144', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '3', 'pow', 'tanh', 'atan', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '2', 'x', '+', '*', '3', 'pow', 'x', '-1', '*', '/', '-2', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'tan', 'x', '-1', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '/', '-2', '3', 'pow', 'x', '2', '*', '/', '13', '45', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'atanh', 'x', '-1', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '/', '-5', '72', 'pow', 'x', '4', '*', '/', '-1', '6', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-3', 'exp', '*', '-1', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-3', '+', 'pow', 'x', '3', '+', '*', '3', 'x', '+', '*', '/', '-5', '8', 'pow', 'x', '4', '*', '/', '-3', '2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '5', 'acos', '*', '/', '1', '5', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '/', '1', '2', 'pi', '+', '*', '/', '-1', '5', 'x', '*', '/', '-1', '750', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'atan', '*', 'x', 'cos', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '*', '/', '-1', '3', '*', 'pow', 'x', '2', 'pow', 'cos', '2', '3', 'cos', '2', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'asinh', 'x', 'tanh', '1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-1', 'x', '+', '*', '/', '1', '6', 'pow', 'x', '3', 'tanh', '1', '<EOS>']
# expression ['<SOS>', '+', '/', '2', '3', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '/', '2', '3', '+', 'x', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-4', 'pow', '+', 'x', 'exp', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-4', '+', '*', '-14', 'pow', 'x', '2', '+', '*', '8', 'x', '+', '*', '/', '-87', '2', 'pow', 'x', '4', '*', '/', '74', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-5', '*', '-5', 'pow', 'cosh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-10', '+', '*', '/', '-25', '24', 'pow', 'x', '4', '*', '/', '5', '2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'exp', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', 'x', '+', '*', '/', '1', '2', 'pow', 'x', '2', '+', '*', '/', '1', '3', 'pow', 'x', '3', '*', '/', '5', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'atan', '*', '5', 'pow', 'asin', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '/', '1', '2', 'pi', '+', '*', '/', '-23', '750', 'pow', 'x', '3', '*', '/', '-1', '5', 'x', '<EOS>']
# expression ['<SOS>', '*', '2', 'pow', '+', '1', 'cos', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '/', '1', '4', 'pow', 'x', '2', '*', '/', '1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '-5', '+', '*', '-1', 'x', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-5', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '5', '*', 'x', 'pow', '+', '-25', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '78125', '*', 'x', '+', '-15625', '+', '*', '-1', 'pow', 'x', '3', '+', '*', '-625', 'x', '*', '-25', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'exp', '*', '-5', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '-5', 'x', '+', '*', '/', '-125', '6', 'pow', 'x', '3', '+', '*', '/', '25', '2', 'pow', 'x', '2', '*', '/', '625', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'x', 'pow', '+', '3', '*', '2', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '81', '*', 'x', '+', '-27', '+', '*', '-12', 'pow', 'x', '2', '+', '*', '8', 'pow', 'x', '3', '*', '18', 'x', '<EOS>']
# expression ['<SOS>', 'pow', '+', '1', 'pow', 'atan', 'x', '2', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '/', '1', '2', 'pow', 'x', '2', '*', '/', '-11', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '/', '1', '5', '*', 'x', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '15', '*', 'pow', 'x', '2', '+', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'x', '-1', '+', '-4', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '-4', 'pow', 'x', '-1', '+', '*', '/', '1', '6', 'pow', 'x', '2', '*', '/', '3', '40', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'asin', 'asinh', '*', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '2', 'x', '<EOS>']
# expression ['<SOS>', 'sinh', 'asin', '*', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '2', 'x', '*', '/', '8', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'pow', 'asin', '*', '5', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '360', '*', 'pow', 'x', '-1', '+', '72', '+', '*', '-2125', 'pow', 'x', '4', '*', '-300', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '5', 'tanh', '*', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '2', 'x', '*', '/', '-8', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'sinh', 'sinh', 'tan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '2', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'pow', '*', 'pow', 'x', '-1', 'tan', 'x', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '/', '1', '6', 'pow', 'x', '2', '*', '/', '19', '360', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'sinh', 'sinh', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '1', '2', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-3', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '2', '*', 'x', '+', '-6', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'x', 'pow', '+', '-1', 'pow', 'x', '2', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'asin', '*', '/', '1', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '48', '*', 'x', '+', '24', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'atan', '*', 'x', 'tan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'pow', 'x', '2', '*', '/', '1', '3', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '1', '*', '3', 'pow', 'asinh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '/', '1', '2', 'x', '+', '*', '3', 'pow', 'x', '-1', '*', '/', '-17', '120', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'exp', '1', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'exp', '1', '*', 'x', '+', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'atan', '+', 'x', '*', '-1', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'exp', '5', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '-1', 'exp', '5', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'cosh', '*', '2', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-1', '*', 'pow', 'x', '2', 'sinh', '2', '+', '*', '/', '1', '12', '*', 'pow', 'x', '4', '+', '*', '6', 'cosh', '2', 'sinh', '2', 'cosh', '2', '<EOS>']
# expression ['<SOS>', '+', '4', '*', '-2', 'pow', 'tanh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '2', '45', '*', 'pow', 'x', '-1', '+', '-45', '*', 'x', '+', '90', '+', 'pow', 'x', '3', '*', '-15', 'x', '<EOS>']
# expression ['<SOS>', '*', '4', 'pow', '+', 'x', 'sin', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '2', 'pow', 'x', '-1', '+', '*', '/', '1', '6', 'x', '*', '/', '1', '180', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-4', '+', 'x', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-4', '+', '*', '2', 'x', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-2', '+', '*', '-1', 'x', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-1', '+', '*', '-1', 'x', '+', '*', '/', '-1', '2', 'pow', 'x', '2', '*', '/', '1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'atanh', '+', 'x', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '2', '*', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '/', '-1', '16', 'acos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '/', '-1', '32', 'pi', '+', '*', '/', '1', '16', 'x', '*', '/', '1', '96', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'pow', '2', '/', '1', '2', 'pow', 'asinh', 'x', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '1440', '*', 'pow', '2', '/', '1', '2', '*', 'pow', 'x', '/', '1', '2', '+', '1440', '+', '*', '-120', 'pow', 'x', '2', '*', '49', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'cosh', '+', '4', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', 'x', 'sinh', '4', '+', '*', '/', '1', '2', '*', 'pow', 'x', '2', 'cosh', '4', '+', '*', '/', '-1', '8', '*', 'pow', 'x', '4', 'cosh', '4', 'cosh', '4', '<EOS>']
# expression ['<SOS>', '+', 'x', 'sin', '*', '/', '1', '4', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '384', '*', 'x', '+', '480', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', 'x', 'exp', '*', '-2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '+', '3', '+', '*', '-6', 'x', '+', '*', '-4', 'pow', 'x', '3', '*', '6', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'atan', '*', '2', 'pow', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '/', '1', '2', 'pi', '+', '*', '/', '-1', '2', 'x', '*', '/', '1', '24', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '4', 'pow', 'asin', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '90', '*', 'pow', 'x', '-1', '+', '360', '+', '*', '-60', 'pow', 'x', '2', '*', '-17', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', 'x', '*', '-1', 'cos', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-1', '+', 'x', '+', '*', '/', '1', '2', 'pow', 'x', '2', '*', '/', '7', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'x', '*', '-5', 'exp', '*', '-1', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-5', '+', '*', '4', 'x', '+', '*', '/', '-5', '2', 'pow', 'x', '2', '+', '*', '/', '-5', '24', 'pow', 'x', '4', '*', '/', '5', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-1', '+', '*', '-1', 'x', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-1', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'pow', '+', '1', '*', '-1', 'pow', 'x', '4', '/', '-1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '*', '/', '1', '2', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '*', '5', 'x', '*', '5', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '5', '3', '*', 'x', '+', '6', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '4', '*', 'x', 'pow', '+', '5', 'pow', 'x', '2', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '4', '25', '*', 'x', '+', '5', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '20', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '20', '+', 'x', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '5', '*', 'x', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', 'x', '*', '/', '-1', '2', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'cosh', '1', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '-1', '3', '*', 'x', '*', '+', '-3', 'pow', 'x', '2', 'cosh', '1', '<EOS>']
# expression ['<SOS>', 'atan', '*', 'x', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'cos', '*', 'x', '+', '-5', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '5', 'pow', 'x', '3', '+', '*', '/', '-25', '2', 'pow', 'x', '2', '*', '/', '613', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'x', '+', '5', '*', '-1', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '+', '15', '+', '*', '-1', 'pow', 'x', '3', '*', '-3', 'x', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'x', '-1', '+', 'x', '*', '-1', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '120', '*', 'pow', 'x', '2', '+', '-20', '*', '-9', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'asinh', '*', 'x', '+', '1', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '1', '+', 'x', '+', '*', '/', '-1', '2', 'pow', 'x', '3', '*', '/', '-1', '6', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-2', '*', 'x', 'pow', '+', '2', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '8', '*', 'x', '+', '-8', '+', 'pow', 'x', '3', '+', '*', '-2', 'pow', 'x', '2', '*', '4', 'x', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'cos', '3', '-1', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '*', 'pow', 'cos', '3', '-1', '+', '3', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '*', '/', '1', '2', 'pi', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '/', '1', '2', 'pi', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'pow', '+', '1', 'pow', 'atanh', 'x', '2', '/', '-1', '2', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-3', 'acos', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-3', 'x', '<EOS>']
# expression ['<SOS>', '+', 'x', '*', '-1', 'exp', 'tan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-1', '+', '*', '/', '-3', '8', 'pow', 'x', '4', '+', '*', '/', '-1', '2', 'pow', 'x', '2', '*', '/', '-1', '2', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-5', '*', '-1', 'asinh', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-5', '*', '-1', 'x', '<EOS>']
# expression ['<SOS>', '+', '-3', '+', '*', '-1', 'x', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-3', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'tan', '*', 'x', 'acosh', '-2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', 'x', 'acosh', '-2', '*', '/', '1', '3', '*', 'pow', 'x', '3', 'pow', 'acosh', '-2', '3', '<EOS>']
# expression ['<SOS>', '*', '/', '-3', '4', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '4', '*', 'x', '+', '-3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '3', 'pow', 'atanh', 'x', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '3', '+', 'pow', 'x', '/', '1', '2', '+', '*', '/', '1', '6', 'pow', 'x', '/', '5', '2', '*', '/', '31', '360', 'pow', 'x', '/', '9', '2', '<EOS>']
# expression ['<SOS>', '*', '5', 'exp', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '5', 'x', '+', '*', '/', '5', '2', 'pow', 'x', '2', '+', '*', '/', '5', '3', 'pow', 'x', '3', '*', '/', '25', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'tan', '*', 'x', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'sin', 'x', 'cos', '3', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-1', 'x', '+', '*', '/', '1', '6', 'pow', 'x', '3', 'cos', '3', '<EOS>']
# expression ['<SOS>', '*', '4', 'pow', '+', '-1', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-4', '+', '*', '-4', 'x', '+', '*', '-4', 'pow', 'x', '2', '+', '*', '-4', 'pow', 'x', '3', '*', '-4', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '-1', 'sin', '*', '/', '1', '5', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '375', '*', 'x', '+', '-75', '*', '13', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'atan', '+', 'x', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '6', '*', 'x', '+', '12', '*', '-17', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '-2', '+', 'x', '*', '-1', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-3', '+', 'x', '+', '*', '/', '-1', '2', 'pow', 'x', '2', '*', '/', '-1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'exp', 'asinh', 'acosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '0', '<EOS>']
# expression ['<SOS>', '*', '5', '*', 'pow', 'x', '-1', 'pow', 'sin', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3024', '*', 'pow', 'x', '-2', '+', '15120', '*', 'pow', 'x', '2', '+', '2520', '+', '*', '31', 'pow', 'x', '4', '*', '294', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'atan', '*', '4', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '/', '-79', '1734', 'pow', 'x', '4', '+', '*', '/', '2', '17', 'pow', 'x', '2', 'atan', '4', '<EOS>']
# expression ['<SOS>', '*', '4', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '2', '3', '*', 'x', '+', '6', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '5', '*', '-1', 'pow', 'sin', 'x', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '-1', 'pow', 'x', '/', '1', '2', '+', '*', '/', '-1', '1440', 'pow', 'x', '/', '9', '2', '*', '/', '1', '12', 'pow', 'x', '/', '5', '2', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'x', 'pow', '+', 'x', '*', '-1', 'acosh', '-4', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '*', 'pow', 'acosh', '-4', '-4', '+', 'pow', 'x', '3', '+', 'pow', 'acosh', '-4', '3', '+', '*', 'x', 'pow', 'acosh', '-4', '2', '*', 'pow', 'x', '2', 'acosh', '-4', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'x', '/', '1', '2', 'pow', '+', '1', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'pow', 'x', '/', '1', '2', '+', '1', '+', 'pow', 'x', '2', '+', 'pow', 'x', '4', '+', '*', '-1', 'x', '*', '-1', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'x', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '-1', 'x', '+', '*', '/', '-1', '2', 'pow', 'x', '2', '*', '/', '1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '-1', '+', 'x', '*', '-1', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-1', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-4', 'pow', 'tan', 'tanh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '4', '15', '*', 'pow', 'x', '-1', '+', '-15', '*', '-1', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'exp', '+', 'x', '*', '-1', 'exp', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '12', '*', '+', '12', '+', 'pow', 'x', '4', '+', '*', '-6', 'pow', 'x', '2', '*', '-2', 'pow', 'x', '3', 'exp', '-1', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'x', '2', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'asinh', '+', '1', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '/', '-1', '10', '*', 'pow', '5', '/', '1', '2', 'pow', 'x', '2', '+', '*', '/', '-1', '600', '*', 'pow', '5', '/', '1', '2', 'pow', 'x', '4', 'asinh', '2', '<EOS>']
# expression ['<SOS>', 'tan', 'asinh', 'tan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '1', '2', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'asin', '2', 'exp', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '24', '*', '+', '-24', '+', '*', '-1', 'pow', 'x', '4', '+', '*', '-24', 'x', '+', '*', '-12', 'pow', 'x', '2', '*', '-4', 'pow', 'x', '3', 'asin', '2', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'x', 'pow', '+', '-5', '*', '4', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '625', '*', 'x', '+', '125', '+', '*', '64', 'pow', 'x', '3', '+', '*', '80', 'pow', 'x', '2', '*', '100', 'x', '<EOS>']
# expression ['<SOS>', '+', '-1', '*', '-1', '*', 'x', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-1', '+', '*', '-1', 'pow', 'x', '2', '*', '/', '-1', '3', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '3', '+', 'x', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '3', '+', '*', '2', 'x', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', 'pow', 'x', '-1', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', 'pow', 'x', '-1', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-4', '+', 'x', '*', '-1', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-4', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '2', 'pow', 'tan', 'x', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '180', '*', 'pow', 'x', '/', '1', '2', '+', '360', '+', '*', '19', 'pow', 'x', '4', '*', '60', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'asin', 'asin', '*', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '2', 'x', '*', '/', '8', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'pow', '+', 'x', 'exp', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '-2', 'x', '+', '*', '/', '-37', '6', 'pow', 'x', '3', '+', '*', '/', '7', '2', 'pow', 'x', '2', '*', '/', '87', '8', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '-5', '+', 'x', '*', '-1', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-5', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '2', '+', '*', '-1', 'x', '*', '-1', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '2', '+', '*', '-2', 'x', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '*', '/', '-1', '5', 'x', '*', '/', '1', '5', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '/', '1', '5', '+', '*', '/', '-1', '5', 'x', '+', '*', '/', '-1', '10', 'pow', 'x', '2', '*', '/', '1', '120', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'acosh', '-4', '-1', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '24', '*', 'pow', 'acosh', '-4', '-1', '+', '24', '+', 'pow', 'x', '4', '*', '12', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'tan', '+', 'x', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '2', '*', 'x', '+', '4', '*', '5', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '3', '*', '2', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '-1', 'pow', 'x', '2', '*', '/', '1', '12', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '/', '-1', '4', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '24', '*', 'x', '+', '-6', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'sin', '5', '-1', 'tan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '*', 'pow', 'sin', '5', '-1', '+', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', 'x', '*', '-1', 'acos', 'tan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '/', '1', '2', 'pow', 'x', '3', '+', '*', '2', 'x', '*', '/', '-1', '2', 'pi', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'cos', 'x', 'asinh', '5', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-1', '+', '*', '/', '1', '2', 'pow', 'x', '2', '+', '*', '/', '-1', '24', 'pow', 'x', '4', 'asinh', '5', '<EOS>']
# expression ['<SOS>', '*', 'x', '+', 'x', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '1', '+', 'x', '*', '/', '1', '2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '5', '*', '-1', '*', 'x', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '-1', 'pow', 'x', '2', '*', '/', '1', '6', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', 'cos', 'x', 'sin', '1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '/', '-1', '2', 'pow', 'x', '2', '+', '*', '/', '1', '24', 'pow', 'x', '4', 'sin', '1', '<EOS>']
# expression ['<SOS>', '*', '-1', 'atan', '*', '3', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-3', 'x', '*', '9', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-1', '*', '-1', '*', 'x', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-1', '+', '*', '-1', 'pow', 'x', '2', '*', '/', '1', '3', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '/', '1', '5', '*', 'x', 'pow', 'tan', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '/', '1', '5', '+', '*', '/', '-1', '15', 'pow', 'x', '2', '*', '/', '-1', '225', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', 'pow', 'atanh', 'x', '/', '1', '2', '*', '-1', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'pow', 'x', '/', '1', '2', '+', '*', '-1', 'x', '+', '*', '/', '1', '6', 'pow', 'x', '/', '5', '2', '*', '/', '31', '360', 'pow', 'x', '/', '9', '2', '<EOS>']
# expression ['<SOS>', '+', '-6', '*', '-1', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-6', '+', '*', '-1', 'x', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'acos', '*', 'x', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '/', '1', '2', 'pi', '+', '*', '-1', 'pow', 'x', '2', '*', '/', '1', '6', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'x', '-1', '+', '2', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '2', 'pow', 'x', '-1', '+', '*', '/', '-1', '6', 'pow', 'x', '2', '*', '/', '3', '40', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '/', '-1', '5', '*', 'x', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '15', '*', 'pow', 'x', '2', '+', '-3', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', 'x', 'pow', '+', '5', 'exp', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '1296', '*', 'x', '+', '216', '+', '*', '-1', 'pow', 'x', '3', '+', '*', '-36', 'x', '*', '-12', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '5', 'atan', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '5', '2', '*', 'x', '+', '2', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '3', '*', 'x', 'pow', '+', '5', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '3', '625', '*', 'x', '+', '125', '+', '*', '-1', 'pow', 'x', '3', '+', '*', '-25', 'x', '*', '5', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'pow', '*', 'pow', 'x', '-1', 'tan', '5', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'pow', 'x', '/', '-1', '2', 'pow', 'tan', '5', '/', '1', '2', '<EOS>']
# expression ['<SOS>', '+', '4', '*', 'x', 'pow', 'tan', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '/', '-1', '3', 'pow', 'x', '2', '*', '/', '-1', '45', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'tanh', '*', '3', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '2', '*', 'x', '+', '6', '*', '-17', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', 'x', '*', '-1', 'asin', '*', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-1', 'x', '*', '/', '-4', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', 'x', '*', 'pow', 'x', '-1', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'pow', 'x', '-1', '+', '*', '/', '1', '2', 'x', '*', '/', '1', '24', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'x', '*', '-1', 'atanh', '*', '/', '1', '4', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '192', '*', 'x', '+', '-240', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'atan', '*', '/', '1', '4', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '192', '*', 'x', '+', '48', '*', '-17', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '3', '*', '-1', 'cos', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '2', '+', '*', '/', '1', '2', 'pow', 'x', '2', '*', '/', '1', '8', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '5', '*', 'pow', 'x', '-1', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '5', '24', '*', 'pow', 'x', '-1', '+', '24', '*', 'pow', 'x', '2', '+', '-12', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'x', '*', '5', 'acos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-6', 'x', '+', '*', '/', '-5', '6', 'pow', 'x', '3', '*', '/', '5', '2', 'pi', '<EOS>']
# expression ['<SOS>', 'tanh', '*', '/', '3', '5', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '3', '125', '*', 'x', '+', '25', '*', '-3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'atan', 'x', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '2', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-5', '*', '-1', '*', 'x', 'pow', 'tanh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-6', '+', '*', '/', '-1', '3', 'pow', 'x', '2', '*', '/', '1', '45', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '-1', 'pow', '+', 'x', 'cosh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-1', '+', 'x', '+', '*', '/', '-1', '2', 'pow', 'x', '2', '*', '/', '7', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'x', '+', '-5', 'pow', 'x', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'pow', 'x', '/', '3', '2', '*', '-5', 'x', '<EOS>']
# expression ['<SOS>', '*', '2', 'acos', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'pi', '*', '-2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '/', '-1', '3', '*', 'x', 'pow', 'tan', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '/', '-1', '3', '+', '*', '/', '1', '9', 'pow', 'x', '2', '*', '/', '1', '135', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'sinh', 'cosh', 'sin', 'x', '<EOS>']
# ...
# expression ['<SOS>', '+', '1', '+', 'x', '*', '-1', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'x', 'atan', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'pow', 'x', '2', '*', '/', '-2', '3', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'cosh', '*', 'exp', '1', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '/', '1', '2', '*', 'pow', 'x', '2', 'exp', '2', '*', '/', '1', '24', '*', 'pow', 'x', '4', 'exp', '4', '<EOS>']
# expression ['<SOS>', '*', '-2', '*', 'x', 'pow', 'sinh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-2', '+', '*', '/', '-7', '180', 'pow', 'x', '4', '*', '/', '1', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '*', '-3', 'atan', 'x', '*', '3', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '+', '4', 'x', 'exp', '*', '-1', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '4', '+', 'pow', 'x', '2', '+', '*', '-3', 'x', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'x', 'pow', '+', '-4', 'cosh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '18', '*', 'x', '+', '6', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '2', 'cos', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '3', '*', '/', '-1', '2', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', 'exp', 'x', 'tan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '1', '+', 'x', '+', '*', '/', '1', '2', 'pow', 'x', '3', '*', '/', '5', '6', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'x', 'pow', '+', '4', 'sinh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '768', '*', 'x', '+', '-192', '+', '*', '-12', 'pow', 'x', '2', '+', '*', '11', 'pow', 'x', '3', '*', '48', 'x', '<EOS>']
# expression ['<SOS>', '*', '/', '1', '3', 'asin', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '18', '*', 'x', '+', '6', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-5', 'acos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '5', 'x', '+', '*', '/', '-5', '2', 'pi', '*', '/', '5', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '/', '1', '3', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '18', '*', 'x', '+', '6', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', 'x', '*', '2', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '+', '9', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-4', '*', 'x', 'pow', 'cosh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '2', '*', 'x', '+', '-2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'atan', 'tan', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'acos', 'x', 'cos', '4', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '+', '*', '/', '1', '2', 'pi', '+', '*', '-1', 'x', '*', '/', '-1', '6', 'pow', 'x', '3', 'cos', '4', '<EOS>']
# expression ['<SOS>', 'pow', 'asin', 'pow', 'x', '2', '/', '1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', 'x', '<EOS>']
# expression ['<SOS>', '*', '4', 'cosh', '*', '5', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '4', '+', '*', '50', 'pow', 'x', '2', '*', '/', '625', '6', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'tanh', 'tan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', 'x', '<EOS>']
# expression ['<SOS>', '+', 'sinh', 'x', 'tanh', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '/', '1', '6', 'pow', 'x', '3', 'tanh', '2', '<EOS>']
# expression ['<SOS>', 'sin', 'tanh', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-5', 'pow', '+', 'x', '*', '-1', 'tan', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-6', 'pow', 'x', '-1', '+', '*', '15', 'pow', 'x', '-3', '+', '*', '/', '-2', '1575', 'pow', 'x', '3', '*', '/', '-1', '35', 'x', '<EOS>']
# expression ['<SOS>', '+', 'x', '*', 'pow', 'x', '-1', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', 'x', '+', '*', '/', '-1', '3', 'pow', 'x', '2', '*', '/', '1', '5', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '-3', 'sin', 'tan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-3', '+', 'x', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'cosh', '*', '2', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '*', '2', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', 'pow', 'x', '2', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '1', '+', 'x', '*', '/', '1', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', 'exp', '-2', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '/', '-1', '6', 'pow', 'x', '3', 'exp', '-2', '<EOS>']
# expression ['<SOS>', '*', 'x', '+', '5', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '6', '*', 'x', '+', '30', '+', '*', '-1', 'pow', 'x', '3', '*', '6', 'x', '<EOS>']
# expression ['<SOS>', '+', 'cosh', '1', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '/', '-1', '3', 'pow', 'x', '3', 'cosh', '1', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'x', '/', '1', '2', 'pow', 'tan', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '45', '*', 'pow', 'x', '/', '-1', '2', '+', '45', '+', '*', '-1', 'pow', 'x', '4', '*', '-15', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-9', 'pow', '+', '3', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-3', '+', 'x', '+', '*', '/', '-1', '3', 'pow', 'x', '2', '+', '*', '/', '-1', '27', 'pow', 'x', '4', '*', '/', '1', '9', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '2', 'asin', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '2', '+', 'x', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', 'x', 'asin', 'cos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '2', 'pi', '<EOS>']
# expression ['<SOS>', '+', '2', 'exp', '*', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '3', '+', '*', '2', 'x', '+', '*', '2', 'pow', 'x', '2', '+', '*', '/', '2', '3', 'pow', 'x', '4', '*', '/', '4', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '*', '-4', 'pow', 'x', '-1', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '-4', 'pow', 'x', '-1', '*', '/', '1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'x', '*', '2', 'pow', 'sinh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '180', '*', 'pow', 'x', '-1', '+', '360', '*', 'pow', 'x', '2', '+', '-240', '*', '7', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '3', 'pow', 'cosh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '3', '+', '*', '/', '-3', '2', 'pow', 'x', '2', '*', '/', '5', '8', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'tan', '*', 'x', 'pow', '+', '1', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '1', '+', '*', '-1', 'x', '+', '*', '-2', 'pow', 'x', '3', '*', '/', '4', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '3', '+', 'x', '*', '-1', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '3', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-1', '*', 'pow', 'atan', 'x', '-1', 'tanh', '5', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '45', '*', 'pow', 'x', '-1', '*', '+', '-45', '*', 'pow', 'x', '2', '+', '-15', '*', '4', 'pow', 'x', '2', 'tanh', '5', '<EOS>']
# expression ['<SOS>', '+', '2', '+', 'x', 'sin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '2', '+', '*', '2', 'x', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'x', 'pow', '+', '-9', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '6561', '*', 'x', '+', '-729', '+', '*', '-1', 'pow', 'x', '3', '+', '*', '-81', 'x', '*', '-9', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'atan', 'x', '*', '-1', 'sinh', '3', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-1', 'x', '+', '*', '-1', 'sinh', '3', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', 'asinh', 'x', 'tan', '1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '/', '-1', '6', 'pow', 'x', '3', 'tan', '1', '<EOS>']
# expression ['<SOS>', '*', '4', 'pow', '+', '1', 'pow', 'x', '2', '/', '-1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '4', '+', '*', '-2', 'pow', 'x', '2', '*', '/', '3', '2', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'sinh', '*', 'x', 'pow', 'tanh', '4', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', 'x', 'pow', 'tanh', '4', '-1', '*', '/', '1', '6', '*', 'pow', 'x', '3', 'pow', 'tanh', '4', '-3', '<EOS>']
# expression ['<SOS>', 'exp', 'cosh', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '6', '*', 'exp', '1', '+', '6', '+', '*', '-1', 'pow', 'x', '4', '*', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'exp', '*', '2', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '+', '1', '+', 'pow', 'x', '2', '*', '/', '7', '12', 'pow', 'x', '4', 'exp', '2', '<EOS>']
# expression ['<SOS>', '*', '-1', 'asin', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-1', 'x', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'x', 'pow', 'cos', '*', '4', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '*', '8', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', 'pow', 'atan', '3', '-1', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '3', '*', 'x', '*', 'pow', 'atan', '3', '-1', '+', '3', '*', '-1', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-2', 'atan', '*', '3', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-6', 'x', '*', '18', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '2', '*', 'pow', 'x', '-1', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '2', '+', '*', '/', '2', '3', 'pow', 'x', '2', '*', '/', '2', '5', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '-1', 'tanh', '*', 'x', 'sinh', '5', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '*', '-1', 'sinh', '5', '*', '/', '1', '3', '*', 'pow', 'x', '2', 'pow', 'sinh', '5', '3', '<EOS>']
# expression ['<SOS>', '*', '/', '1', '4', 'sin', '*', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '/', '1', '2', 'x', '*', '/', '-1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '*', '2', 'pow', 'x', '-1', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '2', 'pow', 'x', '-1', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', 'atan', '*', 'x', 'pow', 'cos', '4', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', 'x', 'pow', 'cos', '4', '-1', '*', '/', '-1', '3', '*', 'pow', 'x', '3', 'pow', 'cos', '4', '-3', '<EOS>']
# expression ['<SOS>', '*', '5', '*', 'x', 'pow', '+', '15', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '10125', '*', 'x', '+', '3375', '+', '*', '-1', 'pow', 'x', '3', '+', '*', '-225', 'x', '*', '15', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '2', 'cosh', '*', '/', '1', '4', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '2', '+', '*', '/', '1', '16', 'pow', 'x', '2', '*', '/', '1', '3072', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '-3', 'pow', '+', 'x', 'atanh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '120', '*', 'pow', 'x', '-1', '+', '-180', '*', 'pow', 'x', '2', '+', '30', '*', '13', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'cos', '*', 'x', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '*', '/', '-1', '2', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '5', 'cosh', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '/', '-35', '24', 'pow', 'x', '4', '*', '/', '5', '2', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'tan', '3', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', 'x', '+', '*', '-1', 'tan', '3', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-4', '+', '*', '-1', 'x', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-3', '+', '*', '/', '1', '2', 'pow', 'x', '2', '+', '*', '-1', 'x', '*', '/', '1', '24', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', 'x', '*', '-1', 'atan', '*', '/', '1', '4', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '192', '*', 'x', '+', '144', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '-5', '*', '/', '1', '5', 'cosh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '/', '-24', '5', '+', '*', '/', '1', '10', 'pow', 'x', '2', '*', '/', '1', '120', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '*', '-3', 'asin', '*', '4', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-32', 'pow', 'x', '3', '*', '-12', 'x', '<EOS>']
# expression ['<SOS>', 'atan', '*', 'x', 'pow', '+', '1', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', 'x', '+', '1', '+', '*', '-1', 'x', '*', '/', '2', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '*', '-1', 'sin', 'sinh', '*', '/', '1', '2', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '-1', '2', 'x', '<EOS>']
# expression ['<SOS>', '+', '5', '*', '4', 'atan', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '5', '+', '*', '4', 'x', '*', '/', '-4', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-25', 'acos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '25', 'x', '+', '*', '/', '-25', '2', 'pi', '*', '/', '25', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-8', 'pow', 'sinh', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '45', '*', 'pow', 'x', '-1', '+', '-360', '*', 'pow', 'x', '2', '+', '60', '*', '-7', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'cos', '*', '/', '1', '2', 'pow', 'x', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '*', '/', '-1', '8', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', 'asinh', '*', 'x', 'pow', 'cosh', '1', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', 'x', 'pow', 'cosh', '1', '-1', '*', '/', '-1', '6', '*', 'pow', 'x', '3', 'pow', 'cosh', '1', '-3', '<EOS>']
# expression ['<SOS>', '*', '/', '1', '2', '*', 'x', 'pow', '+', '4', 'x', '-1', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '512', '*', 'x', '+', '64', '+', '*', '-1', 'pow', 'x', '3', '+', '*', '-16', 'x', '*', '4', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', 'sinh', '+', 'x', 'sinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '*', '/', '1', '2', '*', 'x', '+', '4', '*', '3', 'pow', 'x', '2', '<EOS>']
# expression ['<SOS>', '+', '*', '-1', 'pow', 'x', '/', '1', '2', 'acos', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '/', '1', '2', 'pi', '+', '*', '-1', 'x', '+', '*', '-1', 'pow', 'x', '/', '1', '2', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '*', '-1', 'asinh', 'asinh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '*', '-1', 'x', '*', '/', '1', '3', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '-3', 'pow', '+', '1', 'pow', 'x', '2', '/', '-1', '2', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-2', '+', '*', '/', '-1', '2', 'pow', 'x', '2', '*', '/', '3', '8', 'pow', 'x', '4', '<EOS>']
# expression ['<SOS>', '+', '-3', 'exp', 'tanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '-2', '+', 'x', '+', '*', '/', '1', '2', 'pow', 'x', '2', '+', '*', '/', '-7', '24', 'pow', 'x', '4', '*', '/', '-1', '6', 'pow', 'x', '3', '<EOS>']
# expression ['<SOS>', '+', '1', '*', '-1', 'atanh', 'atanh', 'x', '<EOS>']
# taylor series around 0 ['<SOS>', '+', '1', '+', '*', '-1', 'x', '*', '/', '-2', '3', 'pow', 'x', '3', '<EOS>']

# %%
len(train_idx)
# Out:
# 10065

# %%
len(test_idx)
# Out:
# 1119

# %% [markdown]
# # LSTM Model

# %%
#Defining Encoder and Decoder Class and then Model

class Encoder(nn.Module):
  def __init__(self, vocab_size, embedding_dim=512, num_layers=2, hidden_size=512, dropout=0.2):
    super(Encoder, self).__init__()
    self.embedding_dim = embedding_dim
    self.num_layers = num_layers
    self.hidden_size = hidden_size

    self.embedding = nn.Embedding(
        num_embeddings=vocab_size,
        embedding_dim=self.embedding_dim
    )
    self.lstm = nn.LSTM(
        input_size=self.embedding_dim,
        hidden_size=self.hidden_size,
        num_layers=self.num_layers,
        dropout=dropout,
    )
  """
  input shape (SEQUENCE_LENGTH, BATCH_SIZE)
  h,c shape (HIDDEN_SIZE)
  """
  def forward(self, x):
    embed = self.embedding(x)
    output, (h,c) = self.lstm(embed)
    return h, c

class Decoder(nn.Module):
  def __init__(self, vocab_size, embedding_dim=512, num_layers=2, hidden_size=512, dropout=0.2):
    super(Decoder, self).__init__()
    self.embedding_dim = embedding_dim
    self.num_layers = num_layers
    self.output_size = vocab_size
    self.hidden_size = hidden_size

    self.embedding = nn.Embedding(
        num_embeddings=vocab_size,
        embedding_dim=self.embedding_dim
    )
    self.lstm = nn.LSTM(
        input_size=self.embedding_dim,
        hidden_size=self.hidden_size,
        num_layers=self.num_layers,
        dropout=0.2,
    )
    self.out = nn.Linear(self.hidden_size, self.output_size)
    self.softmax = nn.LogSoftmax(dim=2)
    self.to(device)
  """
  input shape (BATCH_SIZE)
  output shape
  """
  def forward(self, input, h_0, c_0):
    embedded = self.embedding(input.unsqueeze(0))
    output, (h,c) = self.lstm(embedded, (h_0, c_0))
    output = self.out(output)     
    output = self.softmax(output)
    return output.squeeze(0), h , c

class Model(nn.Module):
  def __init__(self, encoder, decoder):
    super(Model, self).__init__()
    self.encoder = encoder
    self.decoder = decoder
    self.to(device)
  """
  Input tensor of shape (SEQUENCE_LENGTH, BATCH_SIZE)
  Output tensor of shape (SEQUENCE_LENGTH, BATCH_SIZE, VOCAB_SIZE)

  if tgt is none use teacher forecasting
  """
  def forward(self, input, tgt=None):
    if len(input.shape) < 2:
        input = input.unsqueeze(1)
    batch_size = input.shape[1]
    h, c = enc(input)
    target = torch.zeros(batch_size, dtype=torch.long).to(device)
    if tgt is None:
      max_seq_length = input.shape[0]
      target[:] = d.token_to_idx['<SOS>']
    else:
      max_seq_length = tgt.shape[1]
      target[:] = tgt[:,0]
    outputs = torch.zeros(max_seq_length, batch_size, dec.output_size, dtype=torch.float).to(device)
    for i in range(max_seq_length):
        prediction, h, c = dec(target, h, c)
        outputs[i] = prediction
        if tgt is None:
          target = prediction.argmax(dim=1)
        else:
          target = tgt[:,i]
    return outputs

# %%
#Instantiate Model

enc = Encoder(len(d.get_alphabet()) + 1)
dec = Decoder(len(d.get_alphabet()) + 1)
m = Model(enc,dec).to(device)

# %%
#Train and Test Epoch

def train_epoch_LSTM(model, train_loader, optimizer, criterion, batch_size=256):
  model.train()
  total_loss = 0
  total_items = 0
  num_correct = 0
  for src, tgt in tqdm(train_loader):
    src = src.to(device)
    tgt = tgt.to(device)

    pred = model(src.squeeze().T,tgt=tgt[:,:-1])

    pred = pred.permute((1,2,0))
    tgt_out = tgt[:,1:]
    loss = criterion(pred, tgt_out)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    total_loss += loss.item()
    total_items += (tgt_out != 0).sum(dim=(0,1))

    num_correct += (torch.logical_and((pred.argmax(dim=1) == tgt_out), (tgt_out != 0))).sum(dim=(0,1))
  return total_loss, num_correct / total_items

def test_epoch_LSTM(model, test_loader, criterion, batch_size=256):
  model.eval()
  total_loss = 0
  total_items = 0
  num_correct = 0
  for src, tgt in tqdm(test_loader):
    src = src.to(device)
    tgt = tgt.to(device)

    pred = model(src.squeeze().T, tgt=tgt[:,:-1])
    pred = pred.permute((1,2,0))
    tgt_out = tgt[:,1:]

    loss = criterion(pred, tgt_out)

    total_loss += loss.item()
    total_items += (tgt_out != 0).sum(dim=(0,1))

    num_correct += (torch.logical_and((logits.argmax(dim=2) == tgt_out), (tgt_out != 0))).sum(dim=(0,1))
  return total_loss, num_correct / total_items

# %%
#Method to train LSTM Model
def train_LSTM(model, train_dataset,  test_dataset, batch_size=256, epochs=20):
  train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
  test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
  criterion = nn.CrossEntropyLoss()


  optim = torch.optim.Adam(model.parameters(), lr=1e-3)
  for e in range(epochs):
    train_loss, train_acc = train_epoch_LSTM(model, train_loader, optim, criterion, batch_size=batch_size)
    test_loss, test_acc = train_epoch_LSTM(model, test_loader, optim, criterion, batch_size=batch_size)
    print(f'Epoch: {e + 1} Training Loss: {train_loss} Training Accuracy: {train_acc} Test Loss: {test_loss} Test Accuracy: {test_acc}')

# %%
#Running training
train_LSTM(m, train_dataset, test_dataset, batch_size=256)
# Out:
# 100%|██████████| 40/40 [00:05<00:00,  7.02it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.63it/s]
# Epoch: 1 Training Loss: 79.44888865947723 Training Accuracy: 0.2158389538526535 Test Loss: 6.193756699562073 Test Accuracy: 0.42160460352897644
# 100%|██████████| 40/40 [00:05<00:00,  7.04it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.71it/s]
# Epoch: 2 Training Loss: 40.253355503082275 Training Accuracy: 0.5204954743385315 Test Loss: 4.453214883804321 Test Accuracy: 0.5615102052688599
# 100%|██████████| 40/40 [00:05<00:00,  6.92it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.50it/s]
# Epoch: 3 Training Loss: 32.8906552195549 Training Accuracy: 0.5804269313812256 Test Loss: 3.918783187866211 Test Accuracy: 0.5971158742904663
# 100%|██████████| 40/40 [00:05<00:00,  6.81it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.32it/s]
# Epoch: 4 Training Loss: 29.63807874917984 Training Accuracy: 0.6141420602798462 Test Loss: 3.545790135860443 Test Accuracy: 0.635553240776062
# 100%|██████████| 40/40 [00:05<00:00,  6.72it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.30it/s]
# Epoch: 5 Training Loss: 26.25686478614807 Training Accuracy: 0.6641221046447754 Test Loss: 3.1763095259666443 Test Accuracy: 0.6830099821090698
# 100%|██████████| 40/40 [00:06<00:00,  6.63it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.15it/s]
# Epoch: 6 Training Loss: 22.864578425884247 Training Accuracy: 0.7054709196090698 Test Loss: 2.723171830177307 Test Accuracy: 0.7162559032440186
# 100%|██████████| 40/40 [00:06<00:00,  6.57it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.00it/s]
# Epoch: 7 Training Loss: 19.83882439136505 Training Accuracy: 0.7431525588035583 Test Loss: 2.3302100002765656 Test Accuracy: 0.7571578621864319
# 100%|██████████| 40/40 [00:06<00:00,  6.53it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.18it/s]
# Epoch: 8 Training Loss: 17.453968107700348 Training Accuracy: 0.7710763216018677 Test Loss: 2.061834752559662 Test Accuracy: 0.782905101776123
# 100%|██████████| 40/40 [00:06<00:00,  6.54it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.13it/s]
# Epoch: 9 Training Loss: 15.570676654577255 Training Accuracy: 0.7931501865386963 Test Loss: 1.8753323554992676 Test Accuracy: 0.7993183135986328
# 100%|██████████| 40/40 [00:06<00:00,  6.60it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.20it/s]
# Epoch: 10 Training Loss: 13.97776660323143 Training Accuracy: 0.8117914795875549 Test Loss: 1.687963455915451 Test Accuracy: 0.8187205195426941
# 100%|██████████| 40/40 [00:06<00:00,  6.65it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.30it/s]
# Epoch: 11 Training Loss: 12.714886635541916 Training Accuracy: 0.8273229598999023 Test Loss: 1.5550552904605865 Test Accuracy: 0.83460932970047
# 100%|██████████| 40/40 [00:05<00:00,  6.68it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.35it/s]
# Epoch: 12 Training Loss: 11.601215869188309 Training Accuracy: 0.8419156670570374 Test Loss: 1.441448301076889 Test Accuracy: 0.8459884524345398
# 100%|██████████| 40/40 [00:05<00:00,  6.70it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.39it/s]
# Epoch: 13 Training Loss: 10.676187172532082 Training Accuracy: 0.8552291989326477 Test Loss: 1.2904720306396484 Test Accuracy: 0.8597797751426697
# 100%|██████████| 40/40 [00:05<00:00,  6.72it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.29it/s]
# Epoch: 14 Training Loss: 9.749161124229431 Training Accuracy: 0.866694450378418 Test Loss: 1.171163260936737 Test Accuracy: 0.8747771382331848
# 100%|██████████| 40/40 [00:05<00:00,  6.75it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.32it/s]
# Epoch: 15 Training Loss: 8.899881973862648 Training Accuracy: 0.8786056041717529 Test Loss: 1.077872559428215 Test Accuracy: 0.8837441205978394
# 100%|██████████| 40/40 [00:05<00:00,  6.74it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.34it/s]
# Epoch: 16 Training Loss: 8.186477705836296 Training Accuracy: 0.8887330889701843 Test Loss: 0.9603532254695892 Test Accuracy: 0.8973256349563599
# 100%|██████████| 40/40 [00:05<00:00,  6.73it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.36it/s]
# Epoch: 17 Training Loss: 7.484002277255058 Training Accuracy: 0.8990306854248047 Test Loss: 0.9212912917137146 Test Accuracy: 0.8998426795005798
# 100%|██████████| 40/40 [00:05<00:00,  6.69it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.38it/s]
# Epoch: 18 Training Loss: 6.802447006106377 Training Accuracy: 0.9074389338493347 Test Loss: 0.8278125524520874 Test Accuracy: 0.912322998046875
# 100%|██████████| 40/40 [00:05<00:00,  6.70it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.35it/s]
# Epoch: 19 Training Loss: 6.1967692375183105 Training Accuracy: 0.9162402749061584 Test Loss: 0.7322542071342468 Test Accuracy: 0.9216046333312988
# 100%|██████████| 40/40 [00:06<00:00,  6.66it/s]
# 100%|██████████| 5/5 [00:00<00:00,  7.38it/s]
# Epoch: 20 Training Loss: 5.650625139474869 Training Accuracy: 0.9244372844696045 Test Loss: 0.6881309002637863 Test Accuracy: 0.9255374670028687

# %% [markdown]
# # Transformer Model

# %%
#Defining Transformer Model

class PositionalEncoding(nn.Module):
    def __init__(self, emb_size: int, dropout, maxlen: int = 5000):
        super(PositionalEncoding, self).__init__()
        den = torch.exp(- torch.arange(0, emb_size, 2) * math.log(10000) / emb_size)
        pos = torch.arange(0, maxlen).reshape(maxlen, 1)
        pos_embedding = torch.zeros((maxlen, emb_size))
        pos_embedding[:, 0::2] = torch.sin(pos * den)
        pos_embedding[:, 1::2] = torch.cos(pos * den)
        pos_embedding = pos_embedding.unsqueeze(-2)

        self.dropout = nn.Dropout(dropout)
        self.register_buffer('pos_embedding', pos_embedding)

    def forward(self, token_embedding):
        return self.dropout(token_embedding +
                            self.pos_embedding[:token_embedding.size(0),:])

def generate_square_subsequent_mask(sz):
    mask = (torch.triu(torch.ones((sz, sz), device=device)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask

def create_mask(src, tgt):
  src_seq_len = src.shape[0]
  tgt_seq_len = tgt.shape[0]

  tgt_mask = generate_square_subsequent_mask(tgt_seq_len)
  src_mask = torch.zeros((src_seq_len, src_seq_len), device=device).type(torch.bool)

  src_padding_mask = (src == 0).transpose(0, 1)
  tgt_padding_mask = (tgt == 0).transpose(0, 1)
  return src_mask, tgt_mask, src_padding_mask, tgt_padding_mask

class TransformerModel(nn.Module):
    def __init__(self, num_encoder_layers, nhead, num_decoder_layers,
                 emb_size, src_vocab_size, tgt_vocab_size,
                 dim_feedforward:int = 512, dropout:float = 0.1):
        super(TransformerModel, self).__init__()
        encoder_layer = nn.TransformerEncoderLayer(d_model=emb_size, nhead=nhead,
                                                dim_feedforward=dim_feedforward)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_encoder_layers)
        decoder_layer = nn.TransformerDecoderLayer(d_model=emb_size, nhead=nhead,
                                                dim_feedforward=dim_feedforward)
        self.transformer_decoder = nn.TransformerDecoder(decoder_layer, num_layers=num_decoder_layers)

        self.generator = nn.Linear(emb_size, tgt_vocab_size)
        self.emb_size = emb_size
        self.src_tok_emb = self.embedding = nn.Embedding(src_vocab_size, emb_size)
        self.tgt_tok_emb = self.embedding = nn.Embedding(tgt_vocab_size, emb_size)
        self.positional_encoding = PositionalEncoding(emb_size, dropout=dropout)

    def forward(self, src, trg, src_mask,
                tgt_mask, src_padding_mask,
                tgt_padding_mask, memory_key_padding_mask):
        src_emb = self.positional_encoding(self.src_tok_emb(src)* math.sqrt(self.emb_size))
        tgt_emb = self.positional_encoding(self.tgt_tok_emb(trg)* math.sqrt(self.emb_size))
        memory = self.transformer_encoder(src_emb, src_mask, src_padding_mask)
        outs = self.transformer_decoder(tgt_emb, memory, tgt_mask, None,
                                        tgt_padding_mask, memory_key_padding_mask)
        return self.generator(outs)

# %%
#Instantiate model
model = TransformerModel(num_encoder_layers=6, nhead=8, num_decoder_layers=6,
                 emb_size=512, src_vocab_size=(len(d.get_alphabet()) + 1), tgt_vocab_size=(len(d.get_alphabet()) + 1),
                 dim_feedforward = 512, dropout = 0.2).to(device)

# %%
#Train and Test Epoch

def train_epoch_transformer(model, train_loader, optimizer, criterion, batch_size):
  model.train()
  total_loss = 0
  num_correct = 0
  total_items = 0
  for src, tgt in tqdm(train_loader):
      src = src.to(device).T
      tgt = tgt.to(device).T

      tgt_input = tgt[:-1, :]

      src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(src, tgt_input)

      logits = model(src, tgt_input, src_mask, tgt_mask,
                                src_padding_mask, tgt_padding_mask, src_padding_mask)

      optimizer.zero_grad()

      tgt_out = tgt[1:,:]
      loss = criterion(logits.reshape(-1, logits.shape[-1]), tgt_out.reshape(-1))

      loss.backward()
      optimizer.step()

      total_loss += loss.item()
      total_items += (tgt_out != 0).sum(dim=(0,1))

      num_correct += (torch.logical_and((logits.argmax(dim=2) == tgt_out), (tgt_out != 0))).sum(dim=(0,1))
  return total_loss / len(train_loader), num_correct / total_items


def test_epoch_transformer(model, test_loader, criterion, batch_size):
  model.eval()
  total_loss = 0
  num_correct = 0
  total_items = 0
  for src, tgt in tqdm(train_loader):
      src = src.to(device).T
      tgt = tgt.to(device).T

      tgt_input = tgt[:-1, :]

      src_mask, tgt_mask, src_padding_mask, tgt_padding_mask = create_mask(src, tgt_input)

      logits = model(src, tgt_input, src_mask, tgt_mask,
                                src_padding_mask, tgt_padding_mask, src_padding_mask)


      tgt_out = tgt[1:,:]
      loss = criterion(logits.reshape(-1, logits.shape[-1]), tgt_out.reshape(-1))


      total_loss += loss.item()
      total_items += (tgt_out != 0).sum(dim=(0,1))

      num_correct += (torch.logical_and((logits.argmax(dim=2) == tgt_out), (tgt_out != 0))).sum(dim=(0,1))
  return total_loss / len(train_loader), num_correct / total_items

# %%
#Defining Transformer Training Method

def train_transformer(model, train_dataset, test_dataset, batch_size=256, epochs=40):
  train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
  test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
  criterion = nn.CrossEntropyLoss()
  
  optim = torch.optim.Adam(model.parameters(), lr=1e-4, betas=(0.9, 0.98), eps=1e-9)
  for e in range(epochs):
    train_loss, train_acc = train_epoch_transformer(model, train_loader, optim, criterion, batch_size=batch_size)
    test_loss, test_acc = train_epoch_transformer(model, test_loader, optim, criterion, batch_size=batch_size)
    print(f'Epoch: {e + 1} Training Loss: {train_loss} Training Accuracy: {train_acc} Test Loss: {test_loss} Test Accuracy: {test_acc}')

# %%
#Running Training 

train_transformer(model,train_dataset, test_dataset)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/torch/nn/functional.py:4999: UserWarning: Support for mismatched src_key_padding_mask and src_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torch/nn/functional.py:4999: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 1 Training Loss: 2.272262266278267 Training Accuracy: 0.16307766735553741 Test Loss: 1.2473761320114136 Test Accuracy: 0.46979549527168274
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 2 Training Loss: 1.017479281127453 Training Accuracy: 0.5379163026809692 Test Loss: 0.8975930333137512 Test Accuracy: 0.5847928524017334
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Epoch: 3 Training Loss: 0.798090772330761 Training Accuracy: 0.6178738474845886 Test Loss: 0.7412149906158447 Test Accuracy: 0.6396958827972412
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 4 Training Loss: 0.6800898924469948 Training Accuracy: 0.6606778502464294 Test Loss: 0.6589356303215027 Test Accuracy: 0.6680650115013123
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 5 Training Loss: 0.6122173696756363 Training Accuracy: 0.6842361688613892 Test Loss: 0.598982059955597 Test Accuracy: 0.6897745132446289
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Epoch: 6 Training Loss: 0.5576515465974807 Training Accuracy: 0.709431529045105 Test Loss: 0.5379390239715576 Test Accuracy: 0.7174095511436462
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Epoch: 7 Training Loss: 0.5138253048062325 Training Accuracy: 0.7298389673233032 Test Loss: 0.5064972639083862 Test Accuracy: 0.7341374158859253
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 8 Training Loss: 0.4776188492774963 Training Accuracy: 0.7459455132484436 Test Loss: 0.4628971040248871 Test Accuracy: 0.7501835227012634
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 9 Training Loss: 0.4452914834022522 Training Accuracy: 0.7596287131309509 Test Loss: 0.4387588858604431 Test Accuracy: 0.767645537853241
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Epoch: 10 Training Loss: 0.41774471700191496 Training Accuracy: 0.7725139260292053 Test Loss: 0.4098490536212921 Test Accuracy: 0.7765600681304932
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 11 Training Loss: 0.3952220693230629 Training Accuracy: 0.784542441368103 Test Loss: 0.3943741977214813 Test Accuracy: 0.786470890045166
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 12 Training Loss: 0.37633374631404876 Training Accuracy: 0.7930680513381958 Test Loss: 0.3759742558002472 Test Accuracy: 0.7938122749328613
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Epoch: 13 Training Loss: 0.35654349997639656 Training Accuracy: 0.802051305770874 Test Loss: 0.35684517621994016 Test Accuracy: 0.8018878102302551
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Epoch: 14 Training Loss: 0.3425788074731827 Training Accuracy: 0.8077487349510193 Test Loss: 0.3371453285217285 Test Accuracy: 0.8112742304801941
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 15 Training Loss: 0.32931220903992653 Training Accuracy: 0.8143615126609802 Test Loss: 0.3308455407619476 Test Accuracy: 0.8135290741920471
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Epoch: 16 Training Loss: 0.3153288722038269 Training Accuracy: 0.8202349543571472 Test Loss: 0.3188141226768494 Test Accuracy: 0.8182485699653625
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 17 Training Loss: 0.30402581095695497 Training Accuracy: 0.8264780640602112 Test Loss: 0.30275996327400206 Test Accuracy: 0.8288410902023315
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 18 Training Loss: 0.29240358211100104 Training Accuracy: 0.8321520090103149 Test Loss: 0.2873951256275177 Test Accuracy: 0.8338751792907715
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 19 Training Loss: 0.2816959202289581 Training Accuracy: 0.8371101021766663 Test Loss: 0.28268670439720156 Test Accuracy: 0.8336654305458069
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 20 Training Loss: 0.270151899009943 Training Accuracy: 0.8428075313568115 Test Loss: 0.27093626856803893 Test Accuracy: 0.8411117196083069
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Epoch: 21 Training Loss: 0.26209590695798396 Training Accuracy: 0.8461637496948242 Test Loss: 0.26526646614074706 Test Accuracy: 0.8457262516021729
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 22 Training Loss: 0.25449068769812583 Training Accuracy: 0.8499190211296082 Test Loss: 0.2566335052251816 Test Accuracy: 0.8511274456977844
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 23 Training Loss: 0.24626580774784088 Training Accuracy: 0.854202389717102 Test Loss: 0.2462901294231415 Test Accuracy: 0.8543785810470581
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 24 Training Loss: 0.23718624822795392 Training Accuracy: 0.8583742380142212 Test Loss: 0.23460252583026886 Test Accuracy: 0.8593602776527405
# 100%|██████████| 40/40 [00:18<00:00,  2.11it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 25 Training Loss: 0.22974552027881145 Training Accuracy: 0.8631328344345093 Test Loss: 0.23037515580654144 Test Accuracy: 0.8631882667541504
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 26 Training Loss: 0.22276787348091603 Training Accuracy: 0.866377592086792 Test Loss: 0.22602900266647338 Test Accuracy: 0.8631882667541504
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 27 Training Loss: 0.21603778526186942 Training Accuracy: 0.8696986436843872 Test Loss: 0.21611455082893372 Test Accuracy: 0.8700577020645142
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Epoch: 28 Training Loss: 0.21032841578125955 Training Accuracy: 0.8726852536201477 Test Loss: 0.21223621368408202 Test Accuracy: 0.871473491191864
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 29 Training Loss: 0.20401919744908809 Training Accuracy: 0.8765109181404114 Test Loss: 0.20461553931236268 Test Accuracy: 0.8760356307029724
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 30 Training Loss: 0.19887803830206394 Training Accuracy: 0.8780893087387085 Test Loss: 0.19379691481590272 Test Accuracy: 0.8817514181137085
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 31 Training Loss: 0.19305700957775115 Training Accuracy: 0.880876362323761 Test Loss: 0.19246895909309386 Test Accuracy: 0.882485568523407
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 32 Training Loss: 0.1879296001046896 Training Accuracy: 0.8842502236366272 Test Loss: 0.1867867022752762 Test Accuracy: 0.8863135576248169
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 33 Training Loss: 0.18126761876046657 Training Accuracy: 0.8876827955245972 Test Loss: 0.1804727643728256 Test Accuracy: 0.8858940601348877
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.38it/s]
# Epoch: 34 Training Loss: 0.17706832103431225 Training Accuracy: 0.8899300694465637 Test Loss: 0.1711764454841614 Test Accuracy: 0.89349764585495
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 35 Training Loss: 0.1715660210698843 Training Accuracy: 0.8934447169303894 Test Loss: 0.1709617555141449 Test Accuracy: 0.8928683996200562
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 36 Training Loss: 0.16793748550117016 Training Accuracy: 0.8946006298065186 Test Loss: 0.17001209259033204 Test Accuracy: 0.8927110433578491
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 37 Training Loss: 0.16470546573400496 Training Accuracy: 0.8968596458435059 Test Loss: 0.162427681684494 Test Accuracy: 0.8976402878761292
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 38 Training Loss: 0.15924151353538035 Training Accuracy: 0.8997758626937866 Test Loss: 0.1581922322511673 Test Accuracy: 0.8990036845207214
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Epoch: 39 Training Loss: 0.15672463215887547 Training Accuracy: 0.9010021686553955 Test Loss: 0.15758674442768097 Test Accuracy: 0.9023597240447998
# 100%|██████████| 40/40 [00:18<00:00,  2.12it/s]
# 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
# Epoch: 40 Training Loss: 0.15127565003931523 Training Accuracy: 0.904153048992157 Test Loss: 0.15667804181575776 Test Accuracy: 0.9035658240318298
